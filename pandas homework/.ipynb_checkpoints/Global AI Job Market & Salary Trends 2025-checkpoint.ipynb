# %% [markdown]
# # Global AI Job Market & Salary Trends 2025
# ### dataset from https://www.kaggle.com/datasets/bismasajjad/global-ai-job-market-and-salary-trends-2025

# %%
import pandas as pd
# Out:
# /var/folders/sc/y88bcdj57rs7dnbrq_w5kpjw0000gn/T/ipykernel_49888/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('ai_job_dataset.csv')
df1 = pd.read_csv('ai_job_dataset1.csv')

# %%
full_df = pd.concat([df, df1])

# %%
full_df.loc[df.employee_residence == 'Netherlands']
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 30     AI00031                   Head of AI       67488             EUR
# 35     AI00036                   Head of AI      126942             USD
# 39     AI00040                Data Engineer      166080             EUR
# 44     AI00045              ML Ops Engineer      158808             EUR
# 102    AI00103                 Data Analyst       91577             EUR
# ...        ...                          ...         ...             ...
# 14921  AI14922  Autonomous Systems Engineer       60902             USD
# 14943  AI14944        AI Research Scientist       86404             USD
# 14965  AI14966           Research Scientist      212794             AUD
# 14974  AI14975     Computer Vision Engineer       40256             USD
# 14998  AI14999                AI Specialist       58764             EUR
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
full_df.describe()
# Out:
#           salary_usd  remote_ratio  years_experience  job_description_length  \
# count   30000.000000  30000.000000      30000.000000            30000.000000
# mean   118670.451700     49.840000          6.309433             1502.083667
# std     62229.977054     40.829278          5.572413              575.418018
# min     16621.000000      0.000000          0.000000              500.000000
# 25%     72575.750000      0.000000          2.000000             1001.000000
# 50%    103206.500000     50.000000          5.000000             1512.000000
# 75%    150921.750000    100.000000         10.000000             1997.000000
# max    410273.000000    100.000000         19.000000             2499.000000
#
#        benefits_score  salary_local
# count    30000.000000  1.500000e+04
# mean         7.501907  8.292366e+05
# std          1.447517  3.425325e+06
# min          5.000000  1.662100e+04
# 25%          6.300000  7.383075e+04
# 50%          7.500000  1.090355e+05
# ...

# %%
full_df.loc[df.employee_residence == 'Netherlands'].hist('salary_usd', by='job_title', legend=True, figsize=(30, 30))
# Out:
# array([[<Axes: title={'center': 'AI Architect'}>,
#         <Axes: title={'center': 'AI Consultant'}>,
#         <Axes: title={'center': 'AI Product Manager'}>,
#         <Axes: title={'center': 'AI Research Scientist'}>],
#        [<Axes: title={'center': 'AI Software Engineer'}>,
#         <Axes: title={'center': 'AI Specialist'}>,
#         <Axes: title={'center': 'Autonomous Systems Engineer'}>,
#         <Axes: title={'center': 'Computer Vision Engineer'}>],
#        [<Axes: title={'center': 'Data Analyst'}>,
#         <Axes: title={'center': 'Data Engineer'}>,
#         <Axes: title={'center': 'Data Scientist'}>,
#         <Axes: title={'center': 'Deep Learning Engineer'}>],
#        [<Axes: title={'center': 'Head of AI'}>,
#         <Axes: title={'center': 'ML Ops Engineer'}>,
#         <Axes: title={'center': 'Machine Learning Engineer'}>,
#         <Axes: title={'center': 'Machine Learning Researcher'}>],
#        [<Axes: title={'center': 'NLP Engineer'}>,
# ...
